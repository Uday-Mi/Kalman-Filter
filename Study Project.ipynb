# %%
import pandas as pd

# %%
data = pd.read_csv("Sampled Data.csv")

# %%
data.head()
# Out:
#    Year  Year Text  Month  Month Text  Day  Day Text  Hour  Hour Text  Minute  \
# 0  2020       2020      1           1    1         1     0          0       0
# 1  2020       2020      1           1    1         1     1          1       0
# 2  2020       2020      1           1    1         1     2          2       0
# 3  2020       2020      1           1    1         1     3          3       0
# 4  2020       2020      1           1    1         1     4          4       0
#
#    Minute Text  ...  Temperature  Dew Point  DHI  DNI  GHI  Relative Humidity  \
# 0            0  ...          7.0       -4.9    0    0    0              42.61
# 1            0  ...          6.5       -4.8    0    0    0              44.18
# 2            0  ...          6.0       -4.8    0    0    0              45.80
# 3            0  ...          5.2       -4.8    0    0    0              48.51
# 4            0  ...          4.9       -4.7    0    0    0              49.70
#
# ...

# %%
import matplotlib as mp

# %%
data.plot(x = 'Time', y = 'Clearsky DHI', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Clearsky DNI', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Clearsky GHI', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Cloud Type', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Fill Flag', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Ozone', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Solar Zenith Angle', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Precipitable Water', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Temperature', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Dew Point', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'DHI', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'GHI', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Relative Humidity', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Surface Albedo', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Pressure', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Wind Direction', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Wind Speed', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data.plot(x = 'Time', y = 'Clearsky DHI', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='Time', ylabel='Clearsky DHI'>
